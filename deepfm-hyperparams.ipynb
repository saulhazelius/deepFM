# %% [markdown]
# #### A PyTorch implementation of the deepFM model with hyperparameters search using Bayesian Optimization

# %%
# !nvidia-smi
# Out:
# Wed Jul 28 17:07:31 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.119.04   Driver Version: 450.119.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import StratifiedKFold
from hyperopt import fmin, hp, tpe, STATUS_OK, Trials
import pandas as pd
import numpy as np
import random
import os
import time

# %%
## set device

# %%
device = 'cuda' if torch.cuda.is_available() == True else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
torch.__version__
# Out:
# '1.7.0'

# %%
## load data

# %%
train_data = '../input/privacychallenge2021/X_train.csv'
y_train_data = '../input/privacychallenge2021/y_train.csv'

# %%
test_data = '../input/privacychallenge2021/X_test.csv'

# %%
## dataframes

# %%
df_train = pd.read_csv(train_data)
df_test = pd.read_csv(test_data)
df_y_train = pd.read_csv(y_train_data)

# %%
X_train = np.array(df_train.values.tolist())

# %%
y_train = np.array(df_y_train.click.values.tolist())

# %%
def set_seeds(seed=999):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
set_seeds()

# %%
# since the min-max feature values in both train and test sets belong to the [-499999 , 499999 ] the one-hot coding length will be 1M per feature (in the Dataloader transform)

# %%
class CleanDataset(Dataset):
    def __init__(self, data, target):
        self.data = data
        self.target = torch.FloatTensor(target)
        
    def __getitem__(self, index):
       
        x = self.data[index]      
        x_feat = np.zeros((1,19),dtype = np.int64)
        x_feat[0] = [500000+x_i for x_i in x]
        y = self.target[index]
        return  x_feat, y
    
    def __len__(self):
        return len(self.data)

# %%
# For this particular problem we are gonna follow the original deepFM model,
# the MLP in the deepFM model will have the structure of 3 layers of equal size, 
# and the number of hidden units will be found by hyperparam opt

# %%
class DeepFM(nn.Module):
  def __init__(self, field_size, emb_dim,
               hidden_units, BATCH, drop_rate):
    super(DeepFM, self).__init__()
    self.embedding = nn.Embedding(field_size, emb_dim)
    self.linear_layer = nn.Linear(19,1)
    self.sigmoid = nn.Sigmoid()
    self.batch = BATCH
    input_dim = self.embed_output_dim = 19 * emb_dim # 
    self.mlp = nn.Sequential(
                nn.Linear(input_dim, hidden_units),
                nn.ReLU(),
                nn.Dropout(drop_rate),
                nn.Linear(hidden_units, hidden_units),
                nn.ReLU(),
                nn.Dropout(drop_rate),
                nn.Linear(hidden_units, hidden_units),
                nn.ReLU(),
                nn.Dropout(drop_rate),
                nn.Linear(hidden_units, 1),
                nn.Dropout(drop_rate)
              )
    


  def forward(self, x):
    embed_x = self.embedding(x)
    square_of_sum = (embed_x.sum(axis=2)) ** 2
    sum_of_square = (embed_x ** 2).sum(axis=2)

    inputs = embed_x.reshape(self.batch,1,self.embed_output_dim)   
    x = x.float()
    linear_term = self.linear_layer(x)
    int_term = 0.5 * (square_of_sum - sum_of_square).sum(2, keepdims=True) # interaction term
    deep_term = self.mlp(inputs)
    out = linear_term + int_term + deep_term 
    deepFM_out = self.sigmoid(out)

    return deepFM_out

# %%
criterion = nn.BCELoss()

# %%
# hyperparams:

# learning rate
# dropout
# hidden units
# embedding units
# batch size

# %%
SPACE = {
    'hidden_units': hp.quniform('hidden_units', low=200, high=900, q=100),
    'embedding_units': hp.quniform('embedding_units', low=4, high=64, q=4),
    'batch_size': hp.quniform('batch_size', low=2, high=18, q=2),
    'dropout': hp.quniform('dropout', low=0.1, high=0.4, q=0.05),
    'learning_rate': hp.uniform('learning_rate', 0.0001, 0.1)
}

# %%
FOLDS = 5
skf = StratifiedKFold(n_splits = FOLDS, random_state=44, shuffle=True)

# %%
def training(params):
  # cv-5 fold training
  # return : mean BCELoss
  print('point: ',params)
  mean_loss = 0.0
  hidden_units = int(params['hidden_units'])
  embedding_units = int(params['embedding_units'])
  batch_size = int(params['batch_size'])
  dropout = params['dropout']
  l_r  = params['learning_rate']
  field_size = int(1e6)
  
  for train_index, test_index in skf.split(X_train, y_train):
      X_train_, X_test = X_train[train_index], X_train[test_index]
      y_train_, y_test = y_train[train_index], y_train[test_index]
      dataset = CleanDataset(X_train_, y_train_)
      test_dataset = CleanDataset(X_test, y_test)
      dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True,
                          num_workers=0)
      test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True,
                          num_workers=0)
      fm_model = DeepFM(field_size,embedding_units,hidden_units,batch_size,dropout).to(device)
      optimizerFM = optim.Adagrad(fm_model.parameters(), lr=l_r)
      n_epochs = 3
    
      for epoch in range(n_epochs):  # 
        start = time.time()
        running_loss = 0.0
        for i, batch in enumerate(dataloader, 0):
        
            x, clicks = batch
            x = x.to(device)
            clicks = clicks.to(device)

            optimizerFM.zero_grad()
            #remove last batch
            if x.shape[0] == batch_size:
                outputs = fm_model(x)
                loss = criterion(outputs.squeeze(), clicks.squeeze())
                loss.backward()
                optimizerFM.step()

                running_loss += loss.item()

                if i % 2000 == 1999:    # print every 10000 mini-batches
                  print('[%d, %5d] loss: %.3f' %
                        (epoch + 1, i + 1, running_loss / 2000))
                  running_loss = 0.0
        print('Time after this epoch training: ', time.time() - start)
      test_loss = get_test_score(fm_model,batch_size,test_dataloader)
      print('Test loss: ',test_loss)
      mean_loss += test_loss
  mean_loss /= FOLDS
  print('mean_loss',mean_loss)
  return {'loss': mean_loss.unsqueeze(0),
           'status': STATUS_OK,
            'model': fm_model, 
            'params': params}

# %%
def get_test_score(fm_model,BATCH,testloader):
  test_loss = 0.0
  criterion = nn.BCELoss()
  'starting evaluation'
  with torch.no_grad():
    for k, batch_test in enumerate(testloader, 0):
      x_clean_test, clicks_clean_test = batch_test
      x_clean_test = x_clean_test.to(device)
      clicks_clean_test = clicks_clean_test.to(device)
      if x_clean_test.shape[0] == BATCH:
        outputs = fm_model(x_clean_test)

        test_loss += criterion(outputs.squeeze(), clicks_clean_test.squeeze())

  test_loss = test_loss / len(testloader)
  return test_loss

# %%
trials = Trials()
fmin(training,SPACE,algo=tpe.suggest, max_evals=20, rstate=np.random.RandomState(789),trials=trials)
# Out:
# point:
# {'batch_size': 10.0, 'dropout': 0.15000000000000002, 'embedding_units': 60.0, 'hidden_units': 700.0, 'learning_rate': 0.0775598873064874}
# [1,  2000] loss: 90.375
# [1,  4000] loss: 89.785
# [1,  6000] loss: 89.980
# [1,  8000] loss: 89.975
# Time after this epoch training:
# 80.08348369598389
# [2,  2000] loss: 89.845
# [2,  4000] loss: 90.040
# [2,  6000] loss: 90.145
# [2,  8000] loss: 90.230
# Time after this epoch training:
# 79.64785385131836
# [3,  2000] loss: 90.025
# [3,  4000] loss: 90.260
# [3,  6000] loss: 90.135
# [3,  8000] loss: 89.815
# Time after this epoch training:
# 79.32791709899902
# Test loss:
# tensor(90.0049, device='cuda:0')
# [1,  2000] loss: 89.942
# [1,  4000] loss: 89.590
# [1,  6000] loss: 90.500
# [1,  8000] loss: 90.110
# Time after this epoch training:
# 79.73240685462952
# [2,  2000] loss: 90.195
# [2,  4000] loss: 90.005
# [2,  6000] loss: 90.155
# [2,  8000] loss: 89.945
# Time after this epoch training:
# 79.6306984424591
# [3,  2000] loss: 89.715
# [3,  4000] loss: 89.950
# [3,  6000] loss: 90.425
# [3,  8000] loss: 90.160
# Time after this epoch training:
# 79.22309184074402
# Test loss:
# tensor(90.0098, device='cuda:0')
# [1,  2000] loss: 89.915
# [1,  4000] loss: 89.740
# [1,  6000] loss: 89.905
# [1,  8000] loss: 89.895
# Time after this epoch training:
# 79.12258458137512
# [2,  2000] loss: 90.000
# [2,  4000] loss: 89.895
# [2,  6000] loss: 89.690
# [2,  8000] loss: 89.925
# Time after this epoch training:
# 79.46415901184082
# [3,  2000] loss: 89.755
# [3,  4000] loss: 90.015
# [3,  6000] loss: 89.935
# [3,  8000] loss: 89.960
# Time after this epoch training:
# 79.01537489891052
# Test loss:
# tensor(89.8145, device='cuda:0')
# [1,  2000] loss: 10.540
# [1,  4000] loss: 9.785
# [1,  6000] loss: 9.885
# [1,  8000] loss: 10.015
# Time after this epoch training:
# 78.9915177822113
# [2,  2000] loss: 10.220
# [2,  4000] loss: 10.055
# [2,  6000] loss: 9.690
# [2,  8000] loss: 9.875
# Time after this epoch training:
# 79.14236235618591
# [3,  2000] loss: 10.115
# [3,  4000] loss: 9.905
# [3,  6000] loss: 9.780
# [3,  8000] loss: 10.055
# Time after this epoch training:
# 78.93119406700134
# Test loss:
# tensor(9.9463, device='cuda:0')
# [1,  2000] loss: 89.075
# [1,  4000] loss: 89.295
# [1,  6000] loss: 89.100
# [1,  8000] loss: 89.050
# Time after this epoch training:
# 78.8309109210968
# [2,  2000] loss: 89.100
# [2,  4000] loss: 89.185
# [2,  6000] loss: 89.020
# [2,  8000] loss: 89.135
# Time after this epoch training:
# 79.0214204788208
# [3,  2000] loss: 89.060
# [3,  4000] loss: 89.365
# [3,  6000] loss: 89.200
# [3,  8000] loss: 88.970
# Time after this epoch training:
# 78.6373963356018
# Test loss:
# tensor(89.0337, device='cuda:0')
# mean_loss
# tensor(73.7618, device='cuda:0')
# point:
# {'batch_size': 18.0, 'dropout': 0.30000000000000004, 'embedding_units': 60.0, 'hidden_units': 800.0, 'learning_rate': 0.04214317958828848}
# [1,  2000] loss: 10.044
# [1,  4000] loss: 10.119
# Time after this epoch training:
# 45.068068981170654
# [2,  2000] loss: 10.067
# [2,  4000] loss: 9.922
# Time after this epoch training:
# 45.49797511100769
# [3,  2000] loss: 10.019
# [3,  4000] loss: 9.953
# Time after this epoch training:
# 44.87350678443909
# Test loss:
# tensor(9.9357, device='cuda:0')
# [1,  2000] loss: 86.048
# [1,  4000] loss: 89.917
# Time after this epoch training:
# 44.83029747009277
# [2,  2000] loss: 89.989
# [2,  4000] loss: 90.017
# Time after this epoch training:
# 45.406599283218384
# [3,  2000] loss: 89.983
# [3,  4000] loss: 90.100
# Time after this epoch training:
# 45.08851337432861
# Test loss:
# tensor(89.9724, device='cuda:0')
# [1,  2000] loss: 12.208
# [1,  4000] loss: 9.869
# Time after this epoch training:
# 44.91661095619202
# [2,  2000] loss: 9.853
# [2,  4000] loss: 10.206
# Time after this epoch training:
# 45.39864206314087
# [3,  2000] loss: 10.311
# [3,  4000] loss: 9.750
# Time after this epoch training:
# 44.88520097732544
# Test loss:
# tensor(10.0528, device='cuda:0')
# [1,  2000] loss: 51.242
# [1,  4000] loss: 10.867
# Time after this epoch training:
# 45.701534271240234
# [2,  2000] loss: 9.850
# [2,  4000] loss: 10.125
# Time after this epoch training:
# 45.00339388847351
# [3,  2000] loss: 9.986
# [3,  4000] loss: 9.914
# Time after this epoch training:
# 44.651620864868164
# Test loss:
# tensor(9.9406, device='cuda:0')
# [1,  2000] loss: 77.626
# [1,  4000] loss: 89.617
# Time after this epoch training:
# 45.25612211227417
# [2,  2000] loss: 89.803
# [2,  4000] loss: 89.700
# Time after this epoch training:
# 45.14231467247009
# [3,  2000] loss: 89.667
# [3,  4000] loss: 89.739
# Time after this epoch training:
# 44.77446246147156
# Test loss:
# tensor(89.7773, device='cuda:0')
# mean_loss
# tensor(41.9357, device='cuda:0')
# point:
# {'batch_size': 8.0, 'dropout': 0.15000000000000002, 'embedding_units': 48.0, 'hidden_units': 300.0, 'learning_rate': 0.0009931775421194828}
# [1,  2000] loss: 82.069
# [1,  4000] loss: 81.338
# [1,  6000] loss: 80.481
# [1,  8000] loss: 80.250
# [1, 10000] loss: 80.577
# Time after this epoch training:
# 83.84217977523804
# [2,  2000] loss: 79.536
# [2,  4000] loss: 80.285
# [2,  6000] loss: 80.162
# [2,  8000] loss: 79.550
# [2, 10000] loss: 79.740
# Time after this epoch training:
# 83.50624489784241
# [3,  2000] loss: 80.144
# [3,  4000] loss: 79.231
# [3,  6000] loss: 79.390
# [3,  8000] loss: 80.181
# [3, 10000] loss: 79.941
# Time after this epoch training:
# 83.8535144329071
# Test loss:
# tensor(79.6324, device='cuda:0')
# [1,  2000] loss: 85.412
# [1,  4000] loss: 85.069
# [1,  6000] loss: 84.531
# [1,  8000] loss: 83.812
# [1, 10000] loss: 83.950
# Time after this epoch training:
# 83.9046745300293
# [2,  2000] loss: 84.037
# [2,  4000] loss: 83.944
# [2,  6000] loss: 83.519
# [2,  8000] loss: 83.313
# [2, 10000] loss: 84.650
# Time after this epoch training:
# 84.4283459186554
# [3,  2000] loss: 84.194
# [3,  4000] loss: 84.031
# [3,  6000] loss: 84.550
# [3,  8000] loss: 84.031
# [3, 10000] loss: 84.412
# Time after this epoch training:
# 83.34671378135681
# Test loss:
# tensor(84.0785, device='cuda:0')
# [1,  2000] loss: 23.656
# [1,  4000] loss: 22.926
# [1,  6000] loss: 22.894
# [1,  8000] loss: 23.294
# [1, 10000] loss: 22.938
# Time after this epoch training:
# 83.11653900146484
# [2,  2000] loss: 22.344
# [2,  4000] loss: 22.257
# [2,  6000] loss: 21.194
# [2,  8000] loss: 21.766
# [2, 10000] loss: 21.008
# Time after this epoch training:
# 83.76152062416077
# [3,  2000] loss: 21.056
# [3,  4000] loss: 20.907
# [3,  6000] loss: 20.731
# [3,  8000] loss: 20.488
# [3, 10000] loss: 20.256
# Time after this epoch training:
# 83.56543493270874
# Test loss:
# tensor(20.5242, device='cuda:0')
# [1,  2000] loss: 27.062
# [1,  4000] loss: 25.901
# [1,  6000] loss: 23.874
# [1,  8000] loss: 23.675
# [1, 10000] loss: 23.206
# Time after this epoch training:
# 83.24693894386292
# [2,  2000] loss: 23.731
# [2,  4000] loss: 23.355
# [2,  6000] loss: 23.106
# [2,  8000] loss: 23.734
# [2, 10000] loss: 24.369
# Time after this epoch training:
# 83.35044050216675
# [3,  2000] loss: 24.234
# [3,  4000] loss: 23.231
# [3,  6000] loss: 23.688
# [3,  8000] loss: 23.469
# [3, 10000] loss: 23.556
# Time after this epoch training:
# 83.7587902545929
# Test loss:
# tensor(23.7358, device='cuda:0')
# [1,  2000] loss: 67.532
# [1,  4000] loss: 68.038
# [1,  6000] loss: 66.151
# [1,  8000] loss: 66.102
# [1, 10000] loss: 65.916
# Time after this epoch training:
# 83.09086108207703
# [2,  2000] loss: 64.182
# [2,  4000] loss: 64.513
# [2,  6000] loss: 64.131
# [2,  8000] loss: 65.115
# [2, 10000] loss: 64.221
# Time after this epoch training:
# 83.17156505584717
# [3,  2000] loss: 64.764
# [3,  4000] loss: 63.425
# [3,  6000] loss: 63.669
# [3,  8000] loss: 63.301
# [3, 10000] loss: 62.931
# Time after this epoch training:
# 83.39451551437378
# Test loss:
# tensor(62.6274, device='cuda:0')
# mean_loss
# tensor(54.1197, device='cuda:0')
# point:
# {'batch_size': 4.0, 'dropout': 0.4, 'embedding_units': 20.0, 'hidden_units': 600.0, 'learning_rate': 0.05256171126328336}
# [1,  2000] loss: 90.037
# [1,  4000] loss: 90.338
# [1,  6000] loss: 89.525
# [1,  8000] loss: 89.612
# [1, 10000] loss: 90.263
# [1, 12000] loss: 90.138
# [1, 14000] loss: 90.200
# [1, 16000] loss: 90.150
# [1, 18000] loss: 90.237
# [1, 20000] loss: 90.100
# Time after this epoch training:
# 103.39247584342957
# [2,  2000] loss: 90.162
# [2,  4000] loss: 89.875
# [2,  6000] loss: 89.750
# [2,  8000] loss: 89.800
# [2, 10000] loss: 90.125
# [2, 12000] loss: 90.688
# [2, 14000] loss: 89.513
# [2, 16000] loss: 90.225
# [2, 18000] loss: 89.763
# [2, 20000] loss: 90.463
# Time after this epoch training:
# 102.40658974647522
# [3,  2000] loss: 90.100
# [3,  4000] loss: 89.925
# [3,  6000] loss: 89.688
# [3,  8000] loss: 89.562
# [3, 10000] loss: 90.412
# [3, 12000] loss: 89.912
# [3, 14000] loss: 90.388
# [3, 16000] loss: 90.300
# [3, 18000] loss: 90.263
# [3, 20000] loss: 89.612
# Time after this epoch training:
# 103.45000910758972
# Test loss:
# tensor(90.0332, device='cuda:0')
# [1,  2000] loss: 11.262
# [1,  4000] loss: 11.738
# [1,  6000] loss: 10.925
# [1,  8000] loss: 9.537
# [1, 10000] loss: 10.100
# [1, 12000] loss: 9.850
# [1, 14000] loss: 9.950
# [1, 16000] loss: 9.475
# [1, 18000] loss: 9.762
# [1, 20000] loss: 10.675
# Time after this epoch training:
# 103.42527174949646
# [2,  2000] loss: 10.463
# [2,  4000] loss: 9.688
# [2,  6000] loss: 9.662
# [2,  8000] loss: 10.025
# [2, 10000] loss: 10.025
# [2, 12000] loss: 9.900
# [2, 14000] loss: 9.750
# [2, 16000] loss: 10.312
# [2, 18000] loss: 9.713
# [2, 20000] loss: 9.988
# Time after this epoch training:
# 102.49798679351807
# [3,  2000] loss: 10.062
# [3,  4000] loss: 10.200
# [3,  6000] loss: 9.925
# [3,  8000] loss: 9.700
# [3, 10000] loss: 9.812
# [3, 12000] loss: 10.125
# [3, 14000] loss: 9.625
# [3, 16000] loss: 10.225
# [3, 18000] loss: 9.800
# [3, 20000] loss: 10.125
# Time after this epoch training:
# 102.28337693214417
# Test loss:
# tensor(9.9473, device='cuda:0')
# [1,  2000] loss: 70.725
# [1,  4000] loss: 16.350
# [1,  6000] loss: 16.238
# [1,  8000] loss: 16.488
# [1, 10000] loss: 12.700
# [1, 12000] loss: 10.275
# [1, 14000] loss: 9.550
# [1, 16000] loss: 9.525
# [1, 18000] loss: 10.000
# [1, 20000] loss: 10.525
# Time after this epoch training:
# 103.22931146621704
# [2,  2000] loss: 10.000
# [2,  4000] loss: 10.037
# [2,  6000] loss: 9.550
# [2,  8000] loss: 10.213
# [2, 10000] loss: 10.037
# [2, 12000] loss: 9.938
# [2, 14000] loss: 9.950
# [2, 16000] loss: 10.300
# [2, 18000] loss: 9.938
# [2, 20000] loss: 9.325
# Time after this epoch training:
# 103.04767537117004
# [3,  2000] loss: 10.200
# [3,  4000] loss: 9.725
# [3,  6000] loss: 9.500
# [3,  8000] loss: 9.963
# [3, 10000] loss: 9.562
# [3, 12000] loss: 9.787
# [3, 14000] loss: 9.662
# [3, 16000] loss: 10.588
# [3, 18000] loss: 10.188
# [3, 20000] loss: 10.325
# Time after this epoch training:
# 101.99032282829285
# Test loss:
# tensor(9.9473, device='cuda:0')
# [1,  2000] loss: 90.138
# [1,  4000] loss: 90.213
# [1,  6000] loss: 89.612
# [1,  8000] loss: 89.875
# [1, 10000] loss: 90.037
# [1, 12000] loss: 90.088
# [1, 14000] loss: 89.750
# [1, 16000] loss: 90.425
# [1, 18000] loss: 90.325
# [1, 20000] loss: 90.037
# Time after this epoch training:
# 102.8720223903656
# [2,  2000] loss: 90.175
# [2,  4000] loss: 90.075
# [2,  6000] loss: 90.000
# [2,  8000] loss: 89.562
# [2, 10000] loss: 89.475
# [2, 12000] loss: 90.300
# [2, 14000] loss: 90.438
# [2, 16000] loss: 90.362
# [2, 18000] loss: 90.513
# [2, 20000] loss: 89.562
# Time after this epoch training:
# 102.43254780769348
# [3,  2000] loss: 90.537
# [3,  4000] loss: 90.025
# [3,  6000] loss: 90.037
# [3,  8000] loss: 89.825
# [3, 10000] loss: 89.675
# [3, 12000] loss: 90.287
# [3, 14000] loss: 89.763
# [3, 16000] loss: 90.138
# [3, 18000] loss: 90.075
# [3, 20000] loss: 90.075
# Time after this epoch training:
# 102.90436840057373
# Test loss:
# tensor(90.0332, device='cuda:0')
# [1,  2000] loss: 10.200
# [1,  4000] loss: 10.113
# [1,  6000] loss: 9.800
# [1,  8000] loss: 10.488
# [1, 10000] loss: 10.225
# [1, 12000] loss: 9.812
# [1, 14000] loss: 9.825
# [1, 16000] loss: 9.787
# [1, 18000] loss: 10.062
# [1, 20000] loss: 10.713
# Time after this epoch training:
# 102.17432451248169
# [2,  2000] loss: 10.375
# [2,  4000] loss: 10.137
# [2,  6000] loss: 9.975
# [2,  8000] loss: 9.512
# [2, 10000] loss: 9.750
# [2, 12000] loss: 10.488
# [2, 14000] loss: 9.988
# [2, 16000] loss: 9.900
# [2, 18000] loss: 10.400
# [2, 20000] loss: 10.775
# Time after this epoch training:
# 102.80842804908752
# [3,  2000] loss: 10.113
# [3,  4000] loss: 10.088
# [3,  6000] loss: 10.025
# [3,  8000] loss: 10.100
# [3, 10000] loss: 10.425
# [3, 12000] loss: 9.650
# [3, 14000] loss: 10.025
# [3, 16000] loss: 10.400
# [3, 18000] loss: 9.988
# [3, 20000] loss: 9.863
# Time after this epoch training:
# 103.38493537902832
# Test loss:
# tensor(10.1328, device='cuda:0')
# mean_loss
# tensor(42.0187, device='cuda:0')
# point:
# {'batch_size': 2.0, 'dropout': 0.25, 'embedding_units': 40.0, 'hidden_units': 800.0, 'learning_rate': 0.04726624527932727}
# [1,  2000] loss: 14.479
# [1,  4000] loss: 15.650
# [1,  6000] loss: 13.900
# [1,  8000] loss: 15.250
# [1, 10000] loss: 14.100
# [1, 12000] loss: 14.175
# [1, 14000] loss: 15.050
# [1, 16000] loss: 14.400
# [1, 18000] loss: 14.475
# [1, 20000] loss: 13.800
# [1, 22000] loss: 11.726
# [1, 24000] loss: 9.675
# [1, 26000] loss: 9.700
# [1, 28000] loss: 10.200
# [1, 30000] loss: 10.025
# [1, 32000] loss: 9.725
# [1, 34000] loss: 10.050
# [1, 36000] loss: 10.875
# [1, 38000] loss: 9.900
# [1, 40000] loss: 9.525
# Time after this epoch training:
# 295.0199992656708
# [2,  2000] loss: 10.175
# [2,  4000] loss: 10.475
# [2,  6000] loss: 9.925
# [2,  8000] loss: 10.300
# [2, 10000] loss: 10.000
# [2, 12000] loss: 9.775
# [2, 14000] loss: 10.075
# [2, 16000] loss: 9.250
# [2, 18000] loss: 10.025
# [2, 20000] loss: 9.850
# [2, 22000] loss: 9.275
# [2, 24000] loss: 9.350
# [2, 26000] loss: 10.300
# [2, 28000] loss: 9.575
# [2, 30000] loss: 11.150
# [2, 32000] loss: 9.975
# [2, 34000] loss: 9.500
# [2, 36000] loss: 11.050
# [2, 38000] loss: 9.800
# [2, 40000] loss: 10.225
# Time after this epoch training:
# 294.45549297332764
# [3,  2000] loss: 10.200
# [3,  4000] loss: 10.425
# [3,  6000] loss: 10.425
# [3,  8000] loss: 10.575
# [3, 10000] loss: 9.050
# [3, 12000] loss: 9.750
# [3, 14000] loss: 9.325
# [3, 16000] loss: 9.775
# [3, 18000] loss: 9.875
# [3, 20000] loss: 10.350
# [3, 22000] loss: 9.725
# [3, 24000] loss: 10.475
# [3, 26000] loss: 10.525
# [3, 28000] loss: 10.225
# [3, 30000] loss: 10.050
# [3, 32000] loss: 9.850
# [3, 34000] loss: 10.175
# [3, 36000] loss: 10.375
# [3, 38000] loss: 9.325
# [3, 40000] loss: 9.425
# Time after this epoch training:
# 294.4829442501068
# Test loss:
# tensor(9.9473, device='cuda:0')
# [1,  2000] loss: 89.925
# [1,  4000] loss: 89.675
# [1,  6000] loss: 89.750
# [1,  8000] loss: 90.375
# [1, 10000] loss: 90.100
# [1, 12000] loss: 90.100
# [1, 14000] loss: 90.500
# [1, 16000] loss: 90.675
# [1, 18000] loss: 89.975
# [1, 20000] loss: 90.075
# [1, 22000] loss: 90.825
# [1, 24000] loss: 89.875
# [1, 26000] loss: 89.975
# [1, 28000] loss: 90.250
# [1, 30000] loss: 90.450
# [1, 32000] loss: 89.400
# [1, 34000] loss: 89.050
# [1, 36000] loss: 90.625
# [1, 38000] loss: 89.225
# [1, 40000] loss: 90.125
# Time after this epoch training:
# 294.8670506477356
# [2,  2000] loss: 90.150
# [2,  4000] loss: 89.850
# [2,  6000] loss: 90.350
# [2,  8000] loss: 88.925
# [2, 10000] loss: 90.200
# [2, 12000] loss: 90.050
# [2, 14000] loss: 91.275
# [2, 16000] loss: 89.625
# [2, 18000] loss: 90.050
# [2, 20000] loss: 89.475
# [2, 22000] loss: 89.650
# [2, 24000] loss: 90.250
# [2, 26000] loss: 90.100
# [2, 28000] loss: 90.250
# [2, 30000] loss: 90.350
# [2, 32000] loss: 89.950
# [2, 34000] loss: 89.450
# ...
# [1, 12000] loss: 58.825
# [1, 14000] loss: 46.614
# [1, 16000] loss: 39.764
# [1, 18000] loss: 16.864
# [1, 20000] loss: 14.188
# Time after this epoch training:
# 192.21083688735962
# [2,  2000] loss: 13.775
# [2,  4000] loss: 13.675
# [2,  6000] loss: 13.887
# [2,  8000] loss: 13.400
# [2, 10000] loss: 13.625
# [2, 12000] loss: 13.075
# [2, 14000] loss: 13.600
# [2, 16000] loss: 13.613
# [2, 18000] loss: 13.225
# [2, 20000] loss: 14.113
# Time after this epoch training:
# 192.35832953453064
# [3,  2000] loss: 13.425
# [3,  4000] loss: 13.325
# [3,  6000] loss: 13.637
# [3,  8000] loss: 12.938
# [3, 10000] loss: 13.450
# [3, 12000] loss: 14.000
# [3, 14000] loss: 13.938
# [3, 16000] loss: 13.600
# [3, 18000] loss: 13.375
# [3, 20000] loss: 13.262
# Time after this epoch training:
# 192.17404890060425
# Test loss:
# tensor(13.7397, device='cuda:0')
# [1,  2000] loss: 89.000
# [1,  4000] loss: 88.463
# [1,  6000] loss: 89.162
# [1,  8000] loss: 89.188
# [1, 10000] loss: 88.812
# [1, 12000] loss: 88.812
# [1, 14000] loss: 89.162
# [1, 16000] loss: 89.013
# [1, 18000] loss: 89.150
# [1, 20000] loss: 88.862
# Time after this epoch training:
# 191.9088237285614
# [2,  2000] loss: 89.400
# [2,  4000] loss: 88.812
# [2,  6000] loss: 89.275
# [2,  8000] loss: 88.912
# [2, 10000] loss: 89.000
# [2, 12000] loss: 88.775
# [2, 14000] loss: 88.625
# [2, 16000] loss: 89.000
# [2, 18000] loss: 89.013
# [2, 20000] loss: 89.250
# Time after this epoch training:
# 192.94410753250122
# [3,  2000] loss: 88.838
# [3,  4000] loss: 89.162
# [3,  6000] loss: 88.500
# [3,  8000] loss: 89.300
# [3, 10000] loss: 89.250
# [3, 12000] loss: 88.812
# [3, 14000] loss: 89.237
# [3, 16000] loss: 88.850
# [3, 18000] loss: 89.000
# [3, 20000] loss: 89.075
# Time after this epoch training:
# 192.06564950942993
# Test loss:
# tensor(88.9302, device='cuda:0')
# [1,  2000] loss: 80.688
# [1,  4000] loss: 80.537
# [1,  6000] loss: 81.275
# [1,  8000] loss: 80.759
# [1, 10000] loss: 74.638
# [1, 12000] loss: 17.587
# [1, 14000] loss: 17.567
# [1, 16000] loss: 10.826
# [1, 18000] loss: 9.525
# [1, 20000] loss: 9.537
# Time after this epoch training:
# 192.50702595710754
# [2,  2000] loss: 10.512
# [2,  4000] loss: 9.650
# [2,  6000] loss: 10.075
# [2,  8000] loss: 9.438
# [2, 10000] loss: 9.713
# [2, 12000] loss: 10.012
# [2, 14000] loss: 10.213
# [2, 16000] loss: 9.475
# [2, 18000] loss: 10.238
# [2, 20000] loss: 10.500
# Time after this epoch training:
# 192.56163001060486
# [3,  2000] loss: 9.863
# [3,  4000] loss: 9.812
# [3,  6000] loss: 10.100
# [3,  8000] loss: 10.312
# [3, 10000] loss: 9.700
# [3, 12000] loss: 9.525
# [3, 14000] loss: 9.988
# [3, 16000] loss: 10.287
# [3, 18000] loss: 10.025
# [3, 20000] loss: 10.062
# Time after this epoch training:
# 192.10509657859802
# Test loss:
# tensor(9.9863, device='cuda:0')
# [1,  2000] loss: 12.175
# [1,  4000] loss: 10.012
# [1,  6000] loss: 10.075
# [1,  8000] loss: 9.412
# [1, 10000] loss: 10.312
# [1, 12000] loss: 9.863
# [1, 14000] loss: 10.012
# [1, 16000] loss: 10.162
# [1, 18000] loss: 9.875
# [1, 20000] loss: 9.650
# Time after this epoch training:
# 192.46910190582275
# [2,  2000] loss: 10.025
# [2,  4000] loss: 10.300
# [2,  6000] loss: 9.725
# [2,  8000] loss: 10.338
# [2, 10000] loss: 10.088
# [2, 12000] loss: 9.588
# [2, 14000] loss: 9.925
# [2, 16000] loss: 10.300
# [2, 18000] loss: 9.912
# [2, 20000] loss: 9.475
# Time after this epoch training:
# 192.39609789848328
# [3,  2000] loss: 10.387
# [3,  4000] loss: 9.950
# [3,  6000] loss: 9.887
# [3,  8000] loss: 9.438
# [3, 10000] loss: 10.075
# [3, 12000] loss: 9.475
# [3, 14000] loss: 10.175
# [3, 16000] loss: 10.463
# [3, 18000] loss: 10.137
# [3, 20000] loss: 9.762
# Time after this epoch training:
# 192.604909658432
# Test loss:
# tensor(9.9766, device='cuda:0')
# [1,  2000] loss: 33.775
# [1,  4000] loss: 11.302
# [1,  6000] loss: 9.875
# [1,  8000] loss: 10.912
# [1, 10000] loss: 9.800
# [1, 12000] loss: 10.050
# [1, 14000] loss: 10.537
# [1, 16000] loss: 9.850
# [1, 18000] loss: 10.200
# [1, 20000] loss: 9.812
# Time after this epoch training:
# 193.58163857460022
# [2,  2000] loss: 10.200
# [2,  4000] loss: 9.412
# [2,  6000] loss: 10.125
# [2,  8000] loss: 9.775
# [2, 10000] loss: 10.387
# [2, 12000] loss: 10.312
# [2, 14000] loss: 9.812
# [2, 16000] loss: 10.150
# [2, 18000] loss: 10.488
# [2, 20000] loss: 10.688
# Time after this epoch training:
# 193.4179253578186
# [3,  2000] loss: 10.150
# [3,  4000] loss: 10.012
# [3,  6000] loss: 10.700
# [3,  8000] loss: 9.875
# [3, 10000] loss: 10.012
# [3, 12000] loss: 9.938
# [3, 14000] loss: 10.575
# [3, 16000] loss: 10.150
# [3, 18000] loss: 9.662
# [3, 20000] loss: 10.213
# Time after this epoch training:
# 194.04724144935608
# Test loss:
# tensor(10.0693, device='cuda:0')
# mean_loss
# tensor(26.5404, device='cuda:0')
# 100%|██████████| 20/20 [7:23:23<00:00, 1330.16s/trial, best loss: 9.942405700683594]
# {'batch_size': 8.0,
#  'dropout': 0.4,
#  'embedding_units': 52.0,
#  'hidden_units': 500.0,
#  'learning_rate': 0.06293870619889874}

# %%
best_model = trials.results[np.argmin([r['loss'] for r in 
    trials.results])]['model']
best_params = trials.results[np.argmin([r['loss'] for r in 
    trials.results])]['params']

# %%
print(best_model)
print(best_params)
# Out:
# DeepFM(
#   (embedding): Embedding(1000000, 52)
#   (linear_layer): Linear(in_features=19, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (mlp): Sequential(
#     (0): Linear(in_features=988, out_features=500, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=500, out_features=500, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.4, inplace=False)
#     (6): Linear(in_features=500, out_features=500, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.4, inplace=False)
#     (9): Linear(in_features=500, out_features=1, bias=True)
#     (10): Dropout(p=0.4, inplace=False)
#   )
# )
# {'batch_size': 8.0, 'dropout': 0.4, 'embedding_units': 52.0, 'hidden_units': 500.0, 'learning_rate': 0.06293870619889874}
